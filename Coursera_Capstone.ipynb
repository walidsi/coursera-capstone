# %% [markdown]
# # Coursera Capstone

# %% [markdown]
# This notebook will be used for the Coursera Captonse course assignments.

# %%
import numpy as np 
import pandas as pd
print("Modules imported successfully!")
# Out:
# Modules imported successfully!

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
